# %%
import pandas as pd
import json 
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
# Show up 5 rows by default
pd.set_option("display.max_rows", 5)

# Increase plots size
# %matplotlib inline
plt.rcParams['figure.figsize'] = (12, 10)

# %% [markdown]
# ### Read JSON Data

# %%
df = pd.read_json("data/AAPL-BALANCE.json")
df2 = pd.read_json("data/AAPL-REV.json")
df3 = pd.read_json("data/AAPL-CAFLOW.json")

# %% [markdown]
# ### Convert Json into PandasDF

# %%
pd.DataFrame(df)
pd.DataFrame(df2)
pd.DataFrame(df3)
# Out:
#          date symbol reportedCurrency          fillingDate  \
# 0  2020-09-26   AAPL              USD           2020-10-30
# 1  2019-09-28   AAPL              USD  2019-10-31 00:00:00
# ..        ...    ...              ...                  ...
# 30 1990-09-30   AAPL              USD           1990-09-30
# 31 1989-09-30   AAPL              USD           1989-09-30
#
#            acceptedDate period    netIncome  depreciationAndAmortization  \
# 0   2020-10-29 18:06:25     FY  57411000000                  11056000000
# 1   2019-10-30 18:12:36     FY  55256000000                  12547000000
# ..                  ...    ...          ...                          ...
# 30           1990-09-30     FY    474900000                    202700000
# 31           1989-09-30     FY    454000000                    124800000
#
#     deferredIncomeTax  stockBasedCompensation  ...  \
# 0          -215000000              6829000000  ...
# 1          -340000000              6068000000  ...
# ..                ...                     ...  ...
# 30          138900000                       0  ...
# 31          111300000                       0  ...
#
#     netCashUsedProvidedByFinancingActivities  effectOfForexChangesOnCash  \
# 0                               -86820000000                           0
# 1                               -90976000000                           0
# ..                                       ...                         ...
# 30                                -454000000                           0
# 31                                 -38300000                           0
#
#     netChangeInCash  cashAtEndOfPeriod  cashAtBeginningOfPeriod  \
# 0      -10435000000        39789000000              50224000000
# 1       24311000000        50224000000              25913000000
# ..              ...                ...                      ...
# 30                0                  0                438300000
# 31                0                  0                372400000
#
#     operatingCashFlow  capitalExpenditure  freeCashFlow  \
# 0         80674000000         -7309000000   73365000000
# 1         69391000000        -10495000000   58896000000
# ..                ...                 ...           ...
# 30          963900000          -224300000     739600000
# 31          507300000          -239000000     268300000
#
#                                                  link  \
# 0   https://www.sec.gov/Archives/edgar/data/320193...
# 1   https://www.sec.gov/Archives/edgar/data/320193...
# ..                                                ...
# 30
# 31
#
#                                             finalLink
# 0   https://www.sec.gov/Archives/edgar/data/320193...
# 1   https://www.sec.gov/Archives/edgar/data/320193...
# ..                                                ...
# 30
# 31
#
# [32 rows x 38 columns]

# %% [markdown]
# ### Drop columns

# %%
dfbalance = df.drop(columns=['reportedCurrency', 'period', 'fillingDate', 'acceptedDate', 'link', 'finalLink', 'symbol'])

# %%
dfbalance
# Out:
#          date  cashAndCashEquivalents  shortTermInvestments  \
# 0  2020-09-26             38016000000           52927000000
# 1  2019-09-28             48844000000           51713000000
# ..        ...                     ...                   ...
# 34 1986-09-30               576200000                     0
# 35 1985-09-30               337000000                     0
#
#     cashAndShortTermInvestments  netReceivables   inventory  \
# 0                   90943000000     37445000000  4061000000
# 1                  100557000000     45804000000  4106000000
# ..                          ...             ...         ...
# 34                    576200000       263100000   108700000
# 35                    337000000       220200000   167000000
#
#     otherCurrentAssets  totalCurrentAssets  propertyPlantEquipmentNet  \
# 0          11264000000        143713000000                36766000000
# 1          12352000000        162819000000                37378000000
# ..                 ...                 ...                        ...
# 34            92900000          1040900000                  107300000
# 35            97900000           822100000                   90400000
#
#     goodwill  ...  totalLiabilities  commonStock  retainedEarnings  \
# 0          0  ...      258549000000  50779000000       14966000000
# 1          0  ...      248028000000  45174000000       45898000000
# ..       ...  ...               ...          ...               ...
# 34         0  ...         466000000            0         474300000
# 35         0  ...         385700000            0         320300000
#
#     accumulatedOtherComprehensiveIncomeLoss  othertotalStockholdersEquity  \
# 0                                -406000000                             0
# 1                                -584000000                             0
# ..                                      ...                           ...
# 34                               -114700000                             0
# 35                                -85200000                             0
#
#     totalStockholdersEquity  totalLiabilitiesAndStockholdersEquity  \
# 0               65339000000                           323888000000
# 1               90488000000                           338516000000
# ..                      ...                                    ...
# 34                694100000                             1160100000
# 35                550500000                              936200000
#
#     totalInvestments     totalDebt      netDebt
# 0       153814000000  112436000000  74420000000
# 1       157054000000  108047000000  59203000000
# ..               ...           ...          ...
# 34                 0             0   -576200000
# 35                 0             0   -337000000
#
# [36 rows x 40 columns]

# %%
dfrevenue = df2.drop(columns=['reportedCurrency', 'fillingDate', 'acceptedDate', 'period', 'link', 'finalLink', 'symbol'])

# %%
dfrevenue
# Out:
#          date       revenue  costOfRevenue   grossProfit  grossProfitRatio  \
# 0  2020-09-26  274515000000   169559000000  104956000000          0.382332
# 1  2019-09-28  260174000000   161782000000   98392000000          0.378178
# ..        ...           ...            ...           ...               ...
# 34 1986-09-30    1901900000      840000000    1061900000          0.558336
# 35 1985-09-30    1918300000     1076000000     842300000          0.439087
#
#     researchAndDevelopmentExpenses  generalAndAdministrativeExpenses  \
# 0                      18752000000                       19916000000
# 1                      16217000000                       18245000000
# ..                             ...                               ...
# 34                               0                         737300000
# 35                               0                         653200000
#
#     sellingAndMarketingExpenses  sellingGeneralAndAdministrativeExpenses  \
# 0                             0                              19916000000
# 1                             0                              18245000000
# ..                          ...                                      ...
# 34                            0                                788400000
# 35                            0                                695000000
#
#     otherExpenses  ...  totalOtherIncomeExpensesNet  incomeBeforeTax  \
# 0       -87000000  ...                    -87000000      67091000000
# 1       422000000  ...                    422000000      65737000000
# ..            ...  ...                          ...              ...
# 34              0  ...                     36200000        309800000
# 35              0  ...                    -27200000        120000000
#
#     incomeBeforeTaxRatio  incomeTaxExpense    netIncome  netIncomeRatio  \
# 0               0.244398        9680000000  57411000000        0.209136
# 1               0.252666       10481000000  55256000000        0.212381
# ..                   ...               ...          ...             ...
# 34              0.162890         155800000    154000000        0.080972
# 35              0.062555          58800000     61200000        0.031903
#
#          eps  epsdiluted  weightedAverageShsOut  weightedAverageShsOutDil
# 0   3.310000    3.280000            17352119000               17528214000
# 1   2.992500    2.972500            18471336000               18595652000
# ..       ...         ...                    ...                       ...
# 34  0.010714    0.010714            14373333333               14373333333
# 35  0.004464    0.004464            13708800000               13708800000
#
# [36 rows x 28 columns]

# %%
dfcashflow = df3.drop(columns=['reportedCurrency', 'fillingDate', 'acceptedDate', 'period', 'link', 'finalLink', 'symbol'])

# %%
dfcashflow
# Out:
#          date    netIncome  depreciationAndAmortization  deferredIncomeTax  \
# 0  2020-09-26  57411000000                  11056000000         -215000000
# 1  2019-09-28  55256000000                  12547000000         -340000000
# ..        ...          ...                          ...                ...
# 30 1990-09-30    474900000                    202700000          138900000
# 31 1989-09-30    454000000                    124800000          111300000
#
#     stockBasedCompensation  changeInWorkingCapital  accountsReceivables  \
# 0               6829000000            -18780000000           6917000000
# 1               6068000000             42628000000            245000000
# ..                     ...                     ...                  ...
# 30                       0               -22800000                    0
# 31                       0              -109000000                    0
#
#     inventory  accountsPayables  otherWorkingCapital  ...  dividendsPaid  \
# 0  -127000000       -4062000000          38321000000  ...   -14081000000
# 1  -289000000       -1923000000          57101000000  ...   -14119000000
# ..        ...               ...                  ...  ...            ...
# 30  119900000                 0           1376300000  ...      -53800000
# 31  -13900000                 0           1399100000  ...      -50300000
#
#     otherFinancingActivites  netCashUsedProvidedByFinancingActivities  \
# 0               -3760000000                              -86820000000
# 1               -2922000000                              -90976000000
# ..                      ...                                       ...
# 30                        0                                -454000000
# 31                        0                                 -38300000
#
#     effectOfForexChangesOnCash  netChangeInCash  cashAtEndOfPeriod  \
# 0                            0     -10435000000        39789000000
# 1                            0      24311000000        50224000000
# ..                         ...              ...                ...
# 30                           0                0                  0
# 31                           0                0                  0
#
#     cashAtBeginningOfPeriod  operatingCashFlow  capitalExpenditure  \
# 0               50224000000        80674000000         -7309000000
# 1               25913000000        69391000000        -10495000000
# ..                      ...                ...                 ...
# 30                438300000          963900000          -224300000
# 31                372400000          507300000          -239000000
#
#     freeCashFlow
# 0    73365000000
# 1    58896000000
# ..           ...
# 30     739600000
# 31     268300000
#
# [32 rows x 31 columns]

# %% [markdown]
# ### Check and count Missing Values

# %%
dfbalance.isnull().sum(axis=1)
# Out:
# 0     0
# 1     0
#      ..
# 34    0
# 35    0
# Length: 36, dtype: int64

# %%
dfrevenue.isnull().sum(axis=1)
# Out:
# 0     0
# 1     0
#      ..
# 34    0
# 35    0
# Length: 36, dtype: int64

# %%
dfcashflow.isnull().sum(axis=1)
# Out:
# 0     0
# 1     0
#      ..
# 30    0
# 31    0
# Length: 32, dtype: int64

# %% [markdown]
# #### So, we drop some columns and check missing values. It's time to go more deeply. Looks like my data needs to be sorter in order to analyze.

# %%
dfbalance = dfbalance.sort_values("date")

# %%
dfrevenue = dfrevenue.sort_values("date")

# %%
dfcashflow = dfcashflow.sort_values("date")

# %% [markdown]
# #### DataType

# %%
dfcashflow.dtypes
# Out:
# date                  datetime64[ns]
# netIncome                      int64
#                            ...
# capitalExpenditure             int64
# freeCashFlow                   int64
# Length: 31, dtype: object

# %%
dfcashflow
# Out:
#          date    netIncome  depreciationAndAmortization  deferredIncomeTax  \
# 31 1989-09-30    454000000                    124800000          111300000
# 30 1990-09-30    474900000                    202700000          138900000
# ..        ...          ...                          ...                ...
# 1  2019-09-28  55256000000                  12547000000         -340000000
# 0  2020-09-26  57411000000                  11056000000         -215000000
#
#     stockBasedCompensation  changeInWorkingCapital  accountsReceivables  \
# 31                       0              -109000000                    0
# 30                       0               -22800000                    0
# ..                     ...                     ...                  ...
# 1               6068000000             42628000000            245000000
# 0               6829000000            -18780000000           6917000000
#
#     inventory  accountsPayables  otherWorkingCapital  ...  dividendsPaid  \
# 31  -13900000                 0           1399100000  ...      -50300000
# 30  119900000                 0           1376300000  ...      -53800000
# ..        ...               ...                  ...  ...            ...
# 1  -289000000       -1923000000          57101000000  ...   -14119000000
# 0  -127000000       -4062000000          38321000000  ...   -14081000000
#
#     otherFinancingActivites  netCashUsedProvidedByFinancingActivities  \
# 31                        0                                 -38300000
# 30                        0                                -454000000
# ..                      ...                                       ...
# 1               -2922000000                              -90976000000
# 0               -3760000000                              -86820000000
#
#     effectOfForexChangesOnCash  netChangeInCash  cashAtEndOfPeriod  \
# 31                           0                0                  0
# 30                           0                0                  0
# ..                         ...              ...                ...
# 1                            0      24311000000        50224000000
# 0                            0     -10435000000        39789000000
#
#     cashAtBeginningOfPeriod  operatingCashFlow  capitalExpenditure  \
# 31                372400000          507300000          -239000000
# 30                438300000          963900000          -224300000
# ..                      ...                ...                 ...
# 1               25913000000        69391000000        -10495000000
# 0               50224000000        80674000000         -7309000000
#
#     freeCashFlow
# 31     268300000
# 30     739600000
# ..           ...
# 1    58896000000
# 0    73365000000
#
# [32 rows x 31 columns]

# %% [markdown]
# #### Mmmm... our numbers looks ugly. Let's fix it.

# %%
sns.set_style('dark')
ax = sns.lineplot(
            x='date', 
            y='netIncome',
            data=dfcashflow,
            color = 'c'
                );
ax.set(xlabel='Year', ylabel='Total Inventory in Billion USD')
plt.show()
